# %%
from io import TextIOWrapper
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, Date, Unicode, UnicodeText, String, Boolean, create_engine
from typing import List
import csv

file_url = r'C:\Users\Cameron\Documents\Projects\Github\sports_database_model\scratch\2020_draft_asset.csv'

Base = declarative_base()

# %%
class DraftAsset(Base):
    __tablename__ = 'team.draft_asset'
    id = Column('id', Integer, nullable=False, primary_key=True)
    owner_team_id = Column('owner_team_id', Integer, nullable=False)
    original_team_id = Column('original_team_id', Integer, nullable=False)
    league_season = Column('league_season', Integer, nullable=False)
    pick_round = Column('pick_round', Integer, nullable=False)
    pick_player_id = Column('pick_player_id', Integer, nullable=False)
    pick_position = Column('pick_position', Integer, nullable=False)
    compensatory = Column('compensatory', Boolean, nullable=False)
    used = Column('used', Boolean, nullable=False)

class DraftPick():
    def __init__(self, round:int, pick:int, team:str, name: str, position_abbrev:str, age:int, alma_mater:str):
        self.round = round
        self.pick_number = pick
        self.team = team
        self.player_name = name
        self.position_abbrev = position_abbrev
        self.age = age
        self.alma_mater = alma_mater
        try:
            self.player_first_name, self.player_last_name = self.player_name.split(' ')
        except ValueError:
            self.player_first_name = self.player_name
            self.player_last_name = 'N/A'
            
    def fix_pfr_name(self):
        self.player_name = self.player_name.split('\\')[0]
        try:
            self.player_first_name, self.player_last_name = self.player_name.split(' ')
        except ValueError:
            self.player_first_name = self.player_name
            self.player_last_name = 'N/A'

# %%
class Team(Base):
    __tablename__ = 'team.nfl_team'
    id = Column('id', Integer, nullable=False, primary_key=True)
    team_name = Column('team_name', String, nullable=False)
    team_abbreviation = Column('team_abbreviation', String, nullable=False)
    team_region = Column('team_region', String, nullable=False)
    team_hq_state_id = Column('team_hq_state_id', Integer, nullable=False)
    team_division_id = Column('team_division_id', Integer, nullable=False)

# %%
engine = create_engine('mssql+pyodbc://sa:Password1@localhost:1433/')
session = Session(engine)
session.query(Team).all()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3239         try:
# -> 3240             return fn()
#    3241         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9768/2077850886.py in <module>
#       1 engine = create_engine('mssql+pyodbc://sa:Password1@localhost:1433/')
#       2 session = Session(engine)
# ----> 3 session.query(Team).all()
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\orm\query.py in all(self)
#    2709                 :ref:`faq_query_deduplicating`
#    2710         """
# -> 2711         return self._iter().all()
#    2712
#    2713     @_generative
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\orm\query.py in _iter(self)
#    2844
#    2845         statement = self._statement_20()
# -> 2846         result = self.session.execute(
#    2847             statement,
#    2848             params,
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1686             )
#    1687         else:
# -> 1688             conn = self._connection_for_bind(bind)
#    1689         result = conn._execute_20(statement, params or {}, execution_options)
#    1690
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in _connection_for_bind(self, engine, execution_options, **kw)
#    1527
#    1528         if self._transaction is not None or self._autobegin():
# -> 1529             return self._transaction._connection_for_bind(
#    1530                 engine, execution_options
#    1531             )
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\orm\session.py in _connection_for_bind(self, bind, execution_options)
#     745                     )
#     746             else:
# --> 747                 conn = bind.connect()
#     748                 local_connect = True
#     749
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3192         """
#    3193
# -> 3194         return self._connection_cls(self, close_with_result=close_with_result)
#    3195
#    3196     @util.deprecated(
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3271
#    3272         """
# -> 3273         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3274
#    3275
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3241         except dialect.dbapi.Error as e:
#    3242             if connection is None:
# -> 3243                 Connection._handle_dbapi_exception_noconnection(
#    3244                     e, dialect, self
#    3245                 )
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2095             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2096         elif should_wrap:
# -> 2097             util.raise_(
#    2098                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2099             )
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3238         dialect = self.dialect
#    3239         try:
# -> 3240             return fn()
#    3241         except dialect.dbapi.Error as e:
#    3242             if connection is None:
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# C:\ProgramData\Miniconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/14/rvf5)

# %%
def read_csv_to_obj(file_name:str, obj:object, header:bool = True) -> List[object]:
    with open(file_name, 'r') as file_stream:
        obj_list = []
        csvreader = csv.reader(file_stream)
        if header:
            head = next(csvreader)
        try:
            for line in csvreader:
                if not line:
                    break
                instance = obj(*line)
                obj_list.append(instance)
        except TypeError as e:
            print(e)
    return obj_list

# %%
pick_list = read_csv_to_obj(file_url, DraftPick)

# %%
for pick in pick_list:
    pick.fix_pfr_name()
    print(pick.__dict__)
# Out:
# {'round': '1', 'pick_number': '1', 'team': 'CIN', 'player_name': 'Joe Burrow', 'position_abbrev': 'QB', 'age': '23', 'alma_mater': 'LSU', 'player_first_name': 'Joe', 'player_last_name': 'Burrow'}
# {'round': '1', 'pick_number': '2', 'team': 'WAS', 'player_name': 'Chase Young', 'position_abbrev': 'DE', 'age': '21', 'alma_mater': 'Ohio St.', 'player_first_name': 'Chase', 'player_last_name': 'Young'}
# {'round': '1', 'pick_number': '3', 'team': 'DET', 'player_name': 'Jeff Okudah', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Ohio St.', 'player_first_name': 'Jeff', 'player_last_name': 'Okudah'}
# {'round': '1', 'pick_number': '4', 'team': 'NYG', 'player_name': 'Andrew Thomas', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'Georgia', 'player_first_name': 'Andrew', 'player_last_name': 'Thomas'}
# {'round': '1', 'pick_number': '5', 'team': 'MIA', 'player_name': 'Tua Tagovailoa', 'position_abbrev': 'QB', 'age': '22', 'alma_mater': 'Alabama', 'player_first_name': 'Tua', 'player_last_name': 'Tagovailoa'}
# {'round': '1', 'pick_number': '6', 'team': 'LAC', 'player_name': 'Justin Herbert', 'position_abbrev': 'QB', 'age': '22', 'alma_mater': 'Oregon', 'player_first_name': 'Justin', 'player_last_name': 'Herbert'}
# {'round': '1', 'pick_number': '7', 'team': 'CAR', 'player_name': 'Derrick Brown', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'Auburn', 'player_first_name': 'Derrick', 'player_last_name': 'Brown'}
# {'round': '1', 'pick_number': '8', 'team': 'ARI', 'player_name': 'Isaiah Simmons', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Clemson', 'player_first_name': 'Isaiah', 'player_last_name': 'Simmons'}
# {'round': '1', 'pick_number': '9', 'team': 'JAX', 'player_name': 'C.J. Henderson', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Florida', 'player_first_name': 'C.J.', 'player_last_name': 'Henderson'}
# {'round': '1', 'pick_number': '10', 'team': 'CLE', 'player_name': 'Jedrick Wills Jr.', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'Alabama', 'player_first_name': 'Jedrick Wills Jr.', 'player_last_name': 'N/A'}
# {'round': '1', 'pick_number': '11', 'team': 'NYJ', 'player_name': 'Mekhi Becton', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'Louisville', 'player_first_name': 'Mekhi', 'player_last_name': 'Becton'}
# {'round': '1', 'pick_number': '12', 'team': 'LVR', 'player_name': 'Henry Ruggs III', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Alabama', 'player_first_name': 'Henry Ruggs III', 'player_last_name': 'N/A'}
# {'round': '1', 'pick_number': '13', 'team': 'TAM', 'player_name': 'Tristan Wirfs', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'Iowa', 'player_first_name': 'Tristan', 'player_last_name': 'Wirfs'}
# {'round': '1', 'pick_number': '14', 'team': 'SFO', 'player_name': 'Javon Kinlaw', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'South Carolina', 'player_first_name': 'Javon', 'player_last_name': 'Kinlaw'}
# {'round': '1', 'pick_number': '15', 'team': 'DEN', 'player_name': 'Jerry Jeudy', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Alabama', 'player_first_name': 'Jerry', 'player_last_name': 'Jeudy'}
# {'round': '1', 'pick_number': '16', 'team': 'ATL', 'player_name': 'AJ Terrell', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Clemson', 'player_first_name': 'AJ', 'player_last_name': 'Terrell'}
# {'round': '1', 'pick_number': '17', 'team': 'DAL', 'player_name': 'CeeDee Lamb', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Oklahoma', 'player_first_name': 'CeeDee', 'player_last_name': 'Lamb'}
# {'round': '1', 'pick_number': '18', 'team': 'MIA', 'player_name': 'Austin Jackson', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'USC', 'player_first_name': 'Austin', 'player_last_name': 'Jackson'}
# {'round': '1', 'pick_number': '19', 'team': 'LVR', 'player_name': 'Damon Arnette', 'position_abbrev': 'CB', 'age': '24', 'alma_mater': 'Ohio St.', 'player_first_name': 'Damon', 'player_last_name': 'Arnette'}
# {'round': '1', 'pick_number': '20', 'team': 'JAX', 'player_name': "K'Lavon Chaisson", 'position_abbrev': 'DE', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': "K'Lavon", 'player_last_name': 'Chaisson'}
# {'round': '1', 'pick_number': '21', 'team': 'PHI', 'player_name': 'Jalen Reagor', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'TCU', 'player_first_name': 'Jalen', 'player_last_name': 'Reagor'}
# {'round': '1', 'pick_number': '22', 'team': 'MIN', 'player_name': 'Justin Jefferson', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Justin', 'player_last_name': 'Jefferson'}
# {'round': '1', 'pick_number': '23', 'team': 'LAC', 'player_name': 'Kenneth Murray', 'position_abbrev': 'LB', 'age': '21', 'alma_mater': 'Oklahoma', 'player_first_name': 'Kenneth', 'player_last_name': 'Murray'}
# {'round': '1', 'pick_number': '24', 'team': 'NOR', 'player_name': 'Cesar Ruiz', 'position_abbrev': 'C', 'age': '21', 'alma_mater': 'Michigan', 'player_first_name': 'Cesar', 'player_last_name': 'Ruiz'}
# {'round': '1', 'pick_number': '25', 'team': 'SFO', 'player_name': 'Brandon Aiyuk', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Arizona St.', 'player_first_name': 'Brandon', 'player_last_name': 'Aiyuk'}
# {'round': '1', 'pick_number': '26', 'team': 'GNB', 'player_name': 'Jordan Love', 'position_abbrev': 'QB', 'age': '21', 'alma_mater': 'Utah St.', 'player_first_name': 'Jordan', 'player_last_name': 'Love'}
# {'round': '1', 'pick_number': '27', 'team': 'SEA', 'player_name': 'Jordyn Brooks', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Texas Tech', 'player_first_name': 'Jordyn', 'player_last_name': 'Brooks'}
# {'round': '1', 'pick_number': '28', 'team': 'BAL', 'player_name': 'Patrick Queen', 'position_abbrev': 'LB', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Patrick', 'player_last_name': 'Queen'}
# {'round': '1', 'pick_number': '29', 'team': 'TEN', 'player_name': 'Isaiah Wilson', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'Georgia', 'player_first_name': 'Isaiah', 'player_last_name': 'Wilson'}
# {'round': '1', 'pick_number': '30', 'team': 'MIA', 'player_name': 'Noah Igbinoghene', 'position_abbrev': 'CB', 'age': '20', 'alma_mater': 'Auburn', 'player_first_name': 'Noah', 'player_last_name': 'Igbinoghene'}
# {'round': '1', 'pick_number': '31', 'team': 'MIN', 'player_name': 'Jeff Gladney', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'TCU', 'player_first_name': 'Jeff', 'player_last_name': 'Gladney'}
# {'round': '1', 'pick_number': '32', 'team': 'KAN', 'player_name': 'Clyde Edwards-Helaire', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Clyde', 'player_last_name': 'Edwards-Helaire'}
# {'round': '2', 'pick_number': '33', 'team': 'CIN', 'player_name': 'Tee Higgins', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Clemson', 'player_first_name': 'Tee', 'player_last_name': 'Higgins'}
# {'round': '2', 'pick_number': '34', 'team': 'IND', 'player_name': 'Michael Pittman Jr.', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'USC', 'player_first_name': 'Michael Pittman Jr.', 'player_last_name': 'N/A'}
# {'round': '2', 'pick_number': '35', 'team': 'DET', 'player_name': "D'Andre Swift", 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Georgia', 'player_first_name': "D'Andre", 'player_last_name': 'Swift'}
# {'round': '2', 'pick_number': '36', 'team': 'NYG', 'player_name': 'Xavier McKinney', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'Alabama', 'player_first_name': 'Xavier', 'player_last_name': 'McKinney'}
# {'round': '2', 'pick_number': '37', 'team': 'NWE', 'player_name': 'Kyle Dugger', 'position_abbrev': 'S', 'age': '24', 'alma_mater': 'Lenoir-Rhyne', 'player_first_name': 'Kyle', 'player_last_name': 'Dugger'}
# {'round': '2', 'pick_number': '38', 'team': 'CAR', 'player_name': 'Yetur Gross-Matos', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Penn St.', 'player_first_name': 'Yetur', 'player_last_name': 'Gross-Matos'}
# {'round': '2', 'pick_number': '39', 'team': 'MIA', 'player_name': 'Robert Hunt', 'position_abbrev': 'G', 'age': '24', 'alma_mater': 'Louisiana', 'player_first_name': 'Robert', 'player_last_name': 'Hunt'}
# {'round': '2', 'pick_number': '40', 'team': 'HOU', 'player_name': 'Ross Blacklock', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'TCU', 'player_first_name': 'Ross', 'player_last_name': 'Blacklock'}
# {'round': '2', 'pick_number': '41', 'team': 'IND', 'player_name': 'Jonathan Taylor', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Wisconsin', 'player_first_name': 'Jonathan', 'player_last_name': 'Taylor'}
# {'round': '2', 'pick_number': '42', 'team': 'JAX', 'player_name': 'Laviska Shenault Jr.', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Colorado', 'player_first_name': 'Laviska Shenault Jr.', 'player_last_name': 'N/A'}
# {'round': '2', 'pick_number': '43', 'team': 'CHI', 'player_name': 'Cole Kmet', 'position_abbrev': 'TE', 'age': '21', 'alma_mater': 'Notre Dame', 'player_first_name': 'Cole', 'player_last_name': 'Kmet'}
# {'round': '2', 'pick_number': '44', 'team': 'CLE', 'player_name': 'Grant Delpit', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Grant', 'player_last_name': 'Delpit'}
# {'round': '2', 'pick_number': '45', 'team': 'TAM', 'player_name': 'Antoine Winfield Jr.', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Minnesota', 'player_first_name': 'Antoine Winfield Jr.', 'player_last_name': 'N/A'}
# {'round': '2', 'pick_number': '46', 'team': 'DEN', 'player_name': 'KJ Hamler', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Penn St.', 'player_first_name': 'KJ', 'player_last_name': 'Hamler'}
# {'round': '2', 'pick_number': '47', 'team': 'ATL', 'player_name': 'Marlon Davidson', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Auburn', 'player_first_name': 'Marlon', 'player_last_name': 'Davidson'}
# {'round': '2', 'pick_number': '48', 'team': 'SEA', 'player_name': 'Darrell Taylor', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'Tennessee', 'player_first_name': 'Darrell', 'player_last_name': 'Taylor'}
# {'round': '2', 'pick_number': '49', 'team': 'PIT', 'player_name': 'Chase Claypool', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Notre Dame', 'player_first_name': 'Chase', 'player_last_name': 'Claypool'}
# {'round': '2', 'pick_number': '50', 'team': 'CHI', 'player_name': 'Jaylon Johnson', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Utah', 'player_first_name': 'Jaylon', 'player_last_name': 'Johnson'}
# {'round': '2', 'pick_number': '51', 'team': 'DAL', 'player_name': 'Trevon Diggs', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Alabama', 'player_first_name': 'Trevon', 'player_last_name': 'Diggs'}
# {'round': '2', 'pick_number': '52', 'team': 'LAR', 'player_name': 'Cam Akers', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Florida St.', 'player_first_name': 'Cam', 'player_last_name': 'Akers'}
# {'round': '2', 'pick_number': '53', 'team': 'PHI', 'player_name': 'Jalen Hurts', 'position_abbrev': 'QB', 'age': '22', 'alma_mater': 'Oklahoma', 'player_first_name': 'Jalen', 'player_last_name': 'Hurts'}
# {'round': '2', 'pick_number': '54', 'team': 'BUF', 'player_name': 'A.J. Epenesa', 'position_abbrev': 'DE', 'age': '21', 'alma_mater': 'Iowa', 'player_first_name': 'A.J.', 'player_last_name': 'Epenesa'}
# {'round': '2', 'pick_number': '55', 'team': 'BAL', 'player_name': 'J.K. Dobbins', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Ohio St.', 'player_first_name': 'J.K.', 'player_last_name': 'Dobbins'}
# {'round': '2', 'pick_number': '56', 'team': 'MIA', 'player_name': 'Raekwon Davis', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Alabama', 'player_first_name': 'Raekwon', 'player_last_name': 'Davis'}
# {'round': '2', 'pick_number': '57', 'team': 'LAR', 'player_name': 'Van Jefferson', 'position_abbrev': 'WR', 'age': '24', 'alma_mater': 'Florida', 'player_first_name': 'Van', 'player_last_name': 'Jefferson'}
# {'round': '2', 'pick_number': '58', 'team': 'MIN', 'player_name': 'Ezra Cleveland', 'position_abbrev': 'T', 'age': '22', 'alma_mater': 'Boise St.', 'player_first_name': 'Ezra', 'player_last_name': 'Cleveland'}
# {'round': '2', 'pick_number': '59', 'team': 'NYJ', 'player_name': 'Denzel Mims', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Baylor', 'player_first_name': 'Denzel', 'player_last_name': 'Mims'}
# {'round': '2', 'pick_number': '60', 'team': 'NWE', 'player_name': 'Josh Uche', 'position_abbrev': 'LB', 'age': '21', 'alma_mater': 'Michigan', 'player_first_name': 'Josh', 'player_last_name': 'Uche'}
# {'round': '2', 'pick_number': '61', 'team': 'TEN', 'player_name': 'Kristian Fulton', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'LSU', 'player_first_name': 'Kristian', 'player_last_name': 'Fulton'}
# {'round': '2', 'pick_number': '62', 'team': 'GNB', 'player_name': 'AJ Dillon', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Boston Col.', 'player_first_name': 'AJ', 'player_last_name': 'Dillon'}
# {'round': '2', 'pick_number': '63', 'team': 'KAN', 'player_name': 'Willie Gay Jr.', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Mississippi St.', 'player_first_name': 'Willie Gay Jr.', 'player_last_name': 'N/A'}
# {'round': '2', 'pick_number': '64', 'team': 'CAR', 'player_name': 'Jeremy Chinn', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Southern Illinois', 'player_first_name': 'Jeremy', 'player_last_name': 'Chinn'}
# {'round': '3', 'pick_number': '65', 'team': 'CIN', 'player_name': 'Logan Wilson', 'position_abbrev': 'LB', 'age': '24', 'alma_mater': 'Wyoming', 'player_first_name': 'Logan', 'player_last_name': 'Wilson'}
# {'round': '3', 'pick_number': '66', 'team': 'WAS', 'player_name': 'Antonio Gibson', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Memphis', 'player_first_name': 'Antonio', 'player_last_name': 'Gibson'}
# {'round': '3', 'pick_number': '67', 'team': 'DET', 'player_name': 'Julian Okwara', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Notre Dame', 'player_first_name': 'Julian', 'player_last_name': 'Okwara'}
# {'round': '3', 'pick_number': '68', 'team': 'NYJ', 'player_name': 'Ashtyn Davis', 'position_abbrev': 'S', 'age': '23', 'alma_mater': 'California', 'player_first_name': 'Ashtyn', 'player_last_name': 'Davis'}
# {'round': '3', 'pick_number': '69', 'team': 'SEA', 'player_name': 'Damien Lewis', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'LSU', 'player_first_name': 'Damien', 'player_last_name': 'Lewis'}
# {'round': '3', 'pick_number': '70', 'team': 'MIA', 'player_name': 'Brandon Jones', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Texas', 'player_first_name': 'Brandon', 'player_last_name': 'Jones'}
# {'round': '3', 'pick_number': '71', 'team': 'BAL', 'player_name': 'Justin Madubuike', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'Texas A&M', 'player_first_name': 'Justin', 'player_last_name': 'Madubuike'}
# {'round': '3', 'pick_number': '72', 'team': 'ARI', 'player_name': 'Josh Jones', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Houston', 'player_first_name': 'Josh', 'player_last_name': 'Jones'}
# {'round': '3', 'pick_number': '73', 'team': 'JAX', 'player_name': 'DaVon Hamilton', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Ohio St.', 'player_first_name': 'DaVon', 'player_last_name': 'Hamilton'}
# {'round': '3', 'pick_number': '74', 'team': 'NOR', 'player_name': 'Zack Baun', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Wisconsin', 'player_first_name': 'Zack', 'player_last_name': 'Baun'}
# {'round': '3', 'pick_number': '75', 'team': 'DET', 'player_name': 'Jonah Jackson', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Ohio St.', 'player_first_name': 'Jonah', 'player_last_name': 'Jackson'}
# {'round': '3', 'pick_number': '76', 'team': 'TAM', 'player_name': "Ke'Shawn Vaughn", 'position_abbrev': 'RB', 'age': '23', 'alma_mater': 'Illinois', 'player_first_name': "Ke'Shawn", 'player_last_name': 'Vaughn'}
# {'round': '3', 'pick_number': '77', 'team': 'DEN', 'player_name': 'Michael Ojemudia', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Iowa', 'player_first_name': 'Michael', 'player_last_name': 'Ojemudia'}
# {'round': '3', 'pick_number': '78', 'team': 'ATL', 'player_name': 'Matt Hennessy', 'position_abbrev': 'C', 'age': '22', 'alma_mater': 'Temple', 'player_first_name': 'Matt', 'player_last_name': 'Hennessy'}
# {'round': '3', 'pick_number': '79', 'team': 'NYJ', 'player_name': 'Jabari Zuniga', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'Florida', 'player_first_name': 'Jabari', 'player_last_name': 'Zuniga'}
# {'round': '3', 'pick_number': '80', 'team': 'LVR', 'player_name': 'Lynn Bowden Jr.', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Kentucky', 'player_first_name': 'Lynn Bowden Jr.', 'player_last_name': 'N/A'}
# {'round': '3', 'pick_number': '81', 'team': 'LVR', 'player_name': 'Bryan Edwards', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'South Carolina', 'player_first_name': 'Bryan', 'player_last_name': 'Edwards'}
# {'round': '3', 'pick_number': '82', 'team': 'DAL', 'player_name': 'Neville Gallimore', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Oklahoma', 'player_first_name': 'Neville', 'player_last_name': 'Gallimore'}
# {'round': '3', 'pick_number': '83', 'team': 'DEN', 'player_name': 'Lloyd Cushenberry III', 'position_abbrev': 'C', 'age': '22', 'alma_mater': 'LSU', 'player_first_name': 'Lloyd Cushenberry III', 'player_last_name': 'N/A'}
# {'round': '3', 'pick_number': '84', 'team': 'LAR', 'player_name': 'Terrell Lewis', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Alabama', 'player_first_name': 'Terrell', 'player_last_name': 'Lewis'}
# {'round': '3', 'pick_number': '85', 'team': 'IND', 'player_name': 'Julian Blackmon', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Utah', 'player_first_name': 'Julian', 'player_last_name': 'Blackmon'}
# {'round': '3', 'pick_number': '86', 'team': 'BUF', 'player_name': 'Zack Moss', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Utah', 'player_first_name': 'Zack', 'player_last_name': 'Moss'}
# {'round': '3', 'pick_number': '87', 'team': 'NWE', 'player_name': 'Anfernee Jennings', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Alabama', 'player_first_name': 'Anfernee', 'player_last_name': 'Jennings'}
# {'round': '3', 'pick_number': '88', 'team': 'CLE', 'player_name': 'Jordan Elliott', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'Texas', 'player_first_name': 'Jordan', 'player_last_name': 'Elliott'}
# {'round': '3', 'pick_number': '89', 'team': 'MIN', 'player_name': 'Cameron Dantzler', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Mississippi St.', 'player_first_name': 'Cameron', 'player_last_name': 'Dantzler'}
# {'round': '3', 'pick_number': '90', 'team': 'HOU', 'player_name': 'Jonathan Greenard', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'Florida', 'player_first_name': 'Jonathan', 'player_last_name': 'Greenard'}
# {'round': '3', 'pick_number': '91', 'team': 'NWE', 'player_name': 'Devin Asiasi', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'UCLA', 'player_first_name': 'Devin', 'player_last_name': 'Asiasi'}
# {'round': '3', 'pick_number': '92', 'team': 'BAL', 'player_name': 'Devin Duvernay', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Texas', 'player_first_name': 'Devin', 'player_last_name': 'Duvernay'}
# {'round': '3', 'pick_number': '93', 'team': 'TEN', 'player_name': 'Darrynton Evans', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Appalachian St.', 'player_first_name': 'Darrynton', 'player_last_name': 'Evans'}
# {'round': '3', 'pick_number': '94', 'team': 'GNB', 'player_name': 'Josiah Deguara', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'Cincinnati', 'player_first_name': 'Josiah', 'player_last_name': 'Deguara'}
# {'round': '3', 'pick_number': '95', 'team': 'DEN', 'player_name': 'McTelvin Agim', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'Arkansas', 'player_first_name': 'McTelvin', 'player_last_name': 'Agim'}
# {'round': '3', 'pick_number': '96', 'team': 'KAN', 'player_name': 'Lucas Niang', 'position_abbrev': 'T', 'age': '22', 'alma_mater': 'TCU', 'player_first_name': 'Lucas', 'player_last_name': 'Niang'}
# {'round': '3', 'pick_number': '97', 'team': 'CLE', 'player_name': 'Jacob Phillips', 'position_abbrev': 'LB', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Jacob', 'player_last_name': 'Phillips'}
# {'round': '3', 'pick_number': '98', 'team': 'BAL', 'player_name': 'Malik Harrison', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Ohio St.', 'player_first_name': 'Malik', 'player_last_name': 'Harrison'}
# {'round': '3', 'pick_number': '99', 'team': 'NYG', 'player_name': 'Matt Peart', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Connecticut', 'player_first_name': 'Matt', 'player_last_name': 'Peart'}
# {'round': '3', 'pick_number': '100', 'team': 'LVR', 'player_name': 'Tanner Muse', 'position_abbrev': 'S', 'age': '24', 'alma_mater': 'Clemson', 'player_first_name': 'Tanner', 'player_last_name': 'Muse'}
# {'round': '3', 'pick_number': '101', 'team': 'NWE', 'player_name': 'Dalton Keene', 'position_abbrev': 'TE', 'age': '21', 'alma_mater': 'Virginia Tech', 'player_first_name': 'Dalton', 'player_last_name': 'Keene'}
# {'round': '3', 'pick_number': '102', 'team': 'PIT', 'player_name': 'Alex Highsmith', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Charlotte', 'player_first_name': 'Alex', 'player_last_name': 'Highsmith'}
# {'round': '3', 'pick_number': '103', 'team': 'PHI', 'player_name': 'Davion Taylor', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Colorado', 'player_first_name': 'Davion', 'player_last_name': 'Taylor'}
# {'round': '3', 'pick_number': '104', 'team': 'LAR', 'player_name': 'Terrell Burgess', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'Utah', 'player_first_name': 'Terrell', 'player_last_name': 'Burgess'}
# {'round': '3', 'pick_number': '105', 'team': 'NOR', 'player_name': 'Adam Trautman', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'Dayton', 'player_first_name': 'Adam', 'player_last_name': 'Trautman'}
# {'round': '3', 'pick_number': '106', 'team': 'BAL', 'player_name': 'Tyre Phillips', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Mississippi St.', 'player_first_name': 'Tyre', 'player_last_name': 'Phillips'}
# {'round': '4', 'pick_number': '107', 'team': 'CIN', 'player_name': 'Akeem Davis-Gaither', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Appalachian St.', 'player_first_name': 'Akeem', 'player_last_name': 'Davis-Gaither'}
# {'round': '4', 'pick_number': '108', 'team': 'WAS', 'player_name': 'Saahdiq Charles', 'position_abbrev': 'T', 'age': '21', 'alma_mater': 'LSU', 'player_first_name': 'Saahdiq', 'player_last_name': 'Charles'}
# {'round': '4', 'pick_number': '109', 'team': 'LVR', 'player_name': 'John Simpson', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Clemson', 'player_first_name': 'John', 'player_last_name': 'Simpson'}
# {'round': '4', 'pick_number': '110', 'team': 'NYG', 'player_name': 'Darnay Holmes', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'UCLA', 'player_first_name': 'Darnay', 'player_last_name': 'Holmes'}
# {'round': '4', 'pick_number': '111', 'team': 'MIA', 'player_name': 'Solomon Kindley', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Georgia', 'player_first_name': 'Solomon', 'player_last_name': 'Kindley'}
# {'round': '4', 'pick_number': '112', 'team': 'LAC', 'player_name': 'Joshua Kelley', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'UCLA', 'player_first_name': 'Joshua', 'player_last_name': 'Kelley'}
# {'round': '4', 'pick_number': '113', 'team': 'CAR', 'player_name': 'Troy Pride Jr.', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Notre Dame', 'player_first_name': 'Troy Pride Jr.', 'player_last_name': 'N/A'}
# {'round': '4', 'pick_number': '114', 'team': 'ARI', 'player_name': 'Leki Fotu', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'Utah', 'player_first_name': 'Leki', 'player_last_name': 'Fotu'}
# {'round': '4', 'pick_number': '115', 'team': 'CLE', 'player_name': 'Harrison Bryant', 'position_abbrev': 'TE', 'age': '22', 'alma_mater': 'Florida Atlantic', 'player_first_name': 'Harrison', 'player_last_name': 'Bryant'}
# {'round': '4', 'pick_number': '116', 'team': 'JAX', 'player_name': 'Ben Bartch', 'position_abbrev': 'G', 'age': '22', 'alma_mater': "Saint John's (MN)", 'player_first_name': 'Ben', 'player_last_name': 'Bartch'}
# {'round': '4', 'pick_number': '117', 'team': 'MIN', 'player_name': 'D.J. Wonnum', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'South Carolina', 'player_first_name': 'D.J.', 'player_last_name': 'Wonnum'}
# {'round': '4', 'pick_number': '118', 'team': 'DEN', 'player_name': 'Albert Okwuegbunam', 'position_abbrev': 'TE', 'age': '22', 'alma_mater': 'Missouri', 'player_first_name': 'Albert', 'player_last_name': 'Okwuegbunam'}
# {'round': '4', 'pick_number': '119', 'team': 'ATL', 'player_name': 'Mykal Walker', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Fresno St.', 'player_first_name': 'Mykal', 'player_last_name': 'Walker'}
# {'round': '4', 'pick_number': '120', 'team': 'NYJ', 'player_name': "La'Mical Perine", 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Florida', 'player_first_name': "La'Mical", 'player_last_name': 'Perine'}
# {'round': '4', 'pick_number': '121', 'team': 'DET', 'player_name': 'Logan Stenberg', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Kentucky', 'player_first_name': 'Logan', 'player_last_name': 'Stenberg'}
# {'round': '4', 'pick_number': '122', 'team': 'IND', 'player_name': 'Jacob Eason', 'position_abbrev': 'QB', 'age': '22', 'alma_mater': 'Washington', 'player_first_name': 'Jacob', 'player_last_name': 'Eason'}
# {'round': '4', 'pick_number': '123', 'team': 'DAL', 'player_name': 'Reggie Robinson II', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'Tulsa', 'player_first_name': 'Reggie Robinson II', 'player_last_name': 'N/A'}
# {'round': '4', 'pick_number': '124', 'team': 'PIT', 'player_name': 'Anthony McFarland Jr.', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Maryland', 'player_first_name': 'Anthony McFarland Jr.', 'player_last_name': 'N/A'}
# {'round': '4', 'pick_number': '125', 'team': 'NYJ', 'player_name': 'James Morgan', 'position_abbrev': 'QB', 'age': '23', 'alma_mater': 'Florida International', 'player_first_name': 'James', 'player_last_name': 'Morgan'}
# {'round': '4', 'pick_number': '126', 'team': 'HOU', 'player_name': 'Charlie Heck', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'North Carolina', 'player_first_name': 'Charlie', 'player_last_name': 'Heck'}
# {'round': '4', 'pick_number': '127', 'team': 'PHI', 'player_name': "K'Von Wallace", 'position_abbrev': 'S', 'age': '23', 'alma_mater': 'Clemson', 'player_first_name': "K'Von", 'player_last_name': 'Wallace'}
# {'round': '4', 'pick_number': '128', 'team': 'BUF', 'player_name': 'Gabriel Davis', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Central Florida', 'player_first_name': 'Gabriel', 'player_last_name': 'Davis'}
# {'round': '4', 'pick_number': '129', 'team': 'NYJ', 'player_name': 'Cameron Clark', 'position_abbrev': 'T', 'age': '22', 'alma_mater': 'Charlotte', 'player_first_name': 'Cameron', 'player_last_name': 'Clark'}
# {'round': '4', 'pick_number': '130', 'team': 'MIN', 'player_name': 'James Lynch', 'position_abbrev': 'DT', 'age': '21', 'alma_mater': 'Baylor', 'player_first_name': 'James', 'player_last_name': 'Lynch'}
# {'round': '4', 'pick_number': '131', 'team': 'ARI', 'player_name': 'Rashard Lawrence', 'position_abbrev': 'DT', 'age': '22', 'alma_mater': 'LSU', 'player_first_name': 'Rashard', 'player_last_name': 'Lawrence'}
# {'round': '4', 'pick_number': '132', 'team': 'MIN', 'player_name': 'Troy Dye', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Oregon', 'player_first_name': 'Troy', 'player_last_name': 'Dye'}
# {'round': '4', 'pick_number': '133', 'team': 'SEA', 'player_name': 'Colby Parkinson', 'position_abbrev': 'TE', 'age': '21', 'alma_mater': 'Stanford', 'player_first_name': 'Colby', 'player_last_name': 'Parkinson'}
# {'round': '4', 'pick_number': '134', 'team': 'ATL', 'player_name': 'Jaylinn Hawkins', 'position_abbrev': 'S', 'age': '23', 'alma_mater': 'California', 'player_first_name': 'Jaylinn', 'player_last_name': 'Hawkins'}
# {'round': '4', 'pick_number': '135', 'team': 'PIT', 'player_name': 'Kevin Dotson', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Louisiana', 'player_first_name': 'Kevin', 'player_last_name': 'Dotson'}
# {'round': '4', 'pick_number': '136', 'team': 'LAR', 'player_name': 'Brycen Hopkins', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'Purdue', 'player_first_name': 'Brycen', 'player_last_name': 'Hopkins'}
# {'round': '4', 'pick_number': '137', 'team': 'JAX', 'player_name': 'Josiah Scott', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Michigan St.', 'player_first_name': 'Josiah', 'player_last_name': 'Scott'}
# {'round': '4', 'pick_number': '138', 'team': 'KAN', 'player_name': "L'Jarius Sneed", 'position_abbrev': 'S', 'age': '23', 'alma_mater': 'Louisiana Tech', 'player_first_name': "L'Jarius", 'player_last_name': 'Sneed'}
# {'round': '4', 'pick_number': '139', 'team': 'LVR', 'player_name': 'Amik Robertson', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Louisiana Tech', 'player_first_name': 'Amik', 'player_last_name': 'Robertson'}
# {'round': '4', 'pick_number': '140', 'team': 'JAX', 'player_name': 'Shaquille Quarterman', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Miami (FL)', 'player_first_name': 'Shaquille', 'player_last_name': 'Quarterman'}
# {'round': '4', 'pick_number': '141', 'team': 'HOU', 'player_name': 'John Reid', 'position_abbrev': 'CB', 'age': '24', 'alma_mater': 'Penn St.', 'player_first_name': 'John', 'player_last_name': 'Reid'}
# {'round': '4', 'pick_number': '142', 'team': 'WAS', 'player_name': 'Antonio Gandy-Golden', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Liberty', 'player_first_name': 'Antonio', 'player_last_name': 'Gandy-Golden'}
# {'round': '4', 'pick_number': '143', 'team': 'BAL', 'player_name': 'Ben Bredeson', 'position_abbrev': 'G', 'age': '22', 'alma_mater': 'Michigan', 'player_first_name': 'Ben', 'player_last_name': 'Bredeson'}
# {'round': '4', 'pick_number': '144', 'team': 'SEA', 'player_name': 'DeeJay Dallas', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Miami (FL)', 'player_first_name': 'DeeJay', 'player_last_name': 'Dallas'}
# {'round': '4', 'pick_number': '145', 'team': 'PHI', 'player_name': 'Jack Driscoll', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Auburn', 'player_first_name': 'Jack', 'player_last_name': 'Driscoll'}
# {'round': '4', 'pick_number': '146', 'team': 'DAL', 'player_name': 'Tyler Biadasz', 'position_abbrev': 'C', 'age': '22', 'alma_mater': 'Wisconsin', 'player_first_name': 'Tyler', 'player_last_name': 'Biadasz'}
# {'round': '5', 'pick_number': '147', 'team': 'CIN', 'player_name': 'Khalid Kareem', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Notre Dame', 'player_first_name': 'Khalid', 'player_last_name': 'Kareem'}
# {'round': '5', 'pick_number': '148', 'team': 'SEA', 'player_name': 'Alton Robinson', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Syracuse', 'player_first_name': 'Alton', 'player_last_name': 'Robinson'}
# {'round': '5', 'pick_number': '149', 'team': 'IND', 'player_name': 'Danny Pinter', 'position_abbrev': 'G', 'age': '24', 'alma_mater': 'Ball St.', 'player_first_name': 'Danny', 'player_last_name': 'Pinter'}
# {'round': '5', 'pick_number': '150', 'team': 'NYG', 'player_name': 'Shane Lemieux', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Oregon', 'player_first_name': 'Shane', 'player_last_name': 'Lemieux'}
# {'round': '5', 'pick_number': '151', 'team': 'LAC', 'player_name': 'Joe Reed', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Virginia', 'player_first_name': 'Joe', 'player_last_name': 'Reed'}
# {'round': '5', 'pick_number': '152', 'team': 'CAR', 'player_name': 'Kenny Robinson Jr.', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'West Virginia', 'player_first_name': 'Kenny Robinson Jr.', 'player_last_name': 'N/A'}
# {'round': '5', 'pick_number': '153', 'team': 'SFO', 'player_name': 'Colton McKivitz', 'position_abbrev': 'T', 'age': '24', 'alma_mater': 'West Virginia', 'player_first_name': 'Colton', 'player_last_name': 'McKivitz'}
# {'round': '5', 'pick_number': '154', 'team': 'MIA', 'player_name': 'Jason Strowbridge', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'North Carolina', 'player_first_name': 'Jason', 'player_last_name': 'Strowbridge'}
# {'round': '5', 'pick_number': '155', 'team': 'CHI', 'player_name': 'Trevis Gipson', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'Tulsa', 'player_first_name': 'Trevis', 'player_last_name': 'Gipson'}
# {'round': '5', 'pick_number': '156', 'team': 'WAS', 'player_name': 'Keith Ismael', 'position_abbrev': 'C', 'age': '22', 'alma_mater': 'San Diego St.', 'player_first_name': 'Keith', 'player_last_name': 'Ismael'}
# {'round': '5', 'pick_number': '157', 'team': 'JAX', 'player_name': 'Daniel Thomas', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Auburn', 'player_first_name': 'Daniel', 'player_last_name': 'Thomas'}
# {'round': '5', 'pick_number': '158', 'team': 'NYJ', 'player_name': 'Bryce Hall', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'Virginia', 'player_first_name': 'Bryce', 'player_last_name': 'Hall'}
# {'round': '5', 'pick_number': '159', 'team': 'NWE', 'player_name': 'Justin Rohrwasser', 'position_abbrev': 'K', 'age': '23', 'alma_mater': 'Marshall', 'player_first_name': 'Justin', 'player_last_name': 'Rohrwasser'}
# {'round': '5', 'pick_number': '160', 'team': 'CLE', 'player_name': 'Nick Harris', 'position_abbrev': 'C', 'age': '21', 'alma_mater': 'Washington', 'player_first_name': 'Nick', 'player_last_name': 'Harris'}
# {'round': '5', 'pick_number': '161', 'team': 'TAM', 'player_name': 'Tyler Johnson', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Minnesota', 'player_first_name': 'Tyler', 'player_last_name': 'Johnson'}
# {'round': '5', 'pick_number': '162', 'team': 'WAS', 'player_name': 'Khaleke Hudson', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Michigan', 'player_first_name': 'Khaleke', 'player_last_name': 'Hudson'}
# {'round': '5', 'pick_number': '163', 'team': 'CHI', 'player_name': 'Kindle Vildor', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Georgia Southern', 'player_first_name': 'Kindle', 'player_last_name': 'Vildor'}
# {'round': '5', 'pick_number': '164', 'team': 'MIA', 'player_name': 'Curtis Weaver', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Boise St.', 'player_first_name': 'Curtis', 'player_last_name': 'Weaver'}
# {'round': '5', 'pick_number': '165', 'team': 'JAX', 'player_name': 'Collin Johnson', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Texas', 'player_first_name': 'Collin', 'player_last_name': 'Johnson'}
# {'round': '5', 'pick_number': '166', 'team': 'DET', 'player_name': 'Quintez Cephus', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Wisconsin', 'player_first_name': 'Quintez', 'player_last_name': 'Cephus'}
# {'round': '5', 'pick_number': '167', 'team': 'BUF', 'player_name': 'Jake Fromm', 'position_abbrev': 'QB', 'age': '22', 'alma_mater': 'Georgia', 'player_first_name': 'Jake', 'player_last_name': 'Fromm'}
# {'round': '5', 'pick_number': '168', 'team': 'PHI', 'player_name': 'John Hightower', 'position_abbrev': 'WR', 'age': '24', 'alma_mater': 'Boise St.', 'player_first_name': 'John', 'player_last_name': 'Hightower'}
# {'round': '5', 'pick_number': '169', 'team': 'MIN', 'player_name': 'Harrison Hand', 'position_abbrev': 'CB', 'age': '21', 'alma_mater': 'Temple', 'player_first_name': 'Harrison', 'player_last_name': 'Hand'}
# {'round': '5', 'pick_number': '170', 'team': 'BAL', 'player_name': 'Broderick Washington Jr.', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Texas Tech', 'player_first_name': 'Broderick Washington Jr.', 'player_last_name': 'N/A'}
# {'round': '5', 'pick_number': '171', 'team': 'HOU', 'player_name': 'Isaiah Coulter', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Rhode Island', 'player_first_name': 'Isaiah', 'player_last_name': 'Coulter'}
# {'round': '5', 'pick_number': '172', 'team': 'DET', 'player_name': 'Jason Huntley', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'New Mexico St.', 'player_first_name': 'Jason', 'player_last_name': 'Huntley'}
# {'round': '5', 'pick_number': '173', 'team': 'CHI', 'player_name': 'Darnell Mooney', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Tulane', 'player_first_name': 'Darnell', 'player_last_name': 'Mooney'}
# {'round': '5', 'pick_number': '174', 'team': 'TEN', 'player_name': 'Larrell Murchison', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'North Carolina St.', 'player_first_name': 'Larrell', 'player_last_name': 'Murchison'}
# {'round': '5', 'pick_number': '175', 'team': 'GNB', 'player_name': 'Kamal Martin', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Minnesota', 'player_first_name': 'Kamal', 'player_last_name': 'Martin'}
# {'round': '5', 'pick_number': '176', 'team': 'MIN', 'player_name': 'K.J. Osborn', 'position_abbrev': 'WR', 'age': '23', 'alma_mater': 'Miami (FL)', 'player_first_name': 'K.J.', 'player_last_name': 'Osborn'}
# {'round': '5', 'pick_number': '177', 'team': 'KAN', 'player_name': 'Michael Danna', 'position_abbrev': 'DE', 'age': '22', 'alma_mater': 'Michigan', 'player_first_name': 'Michael', 'player_last_name': 'Danna'}
# {'round': '5', 'pick_number': '178', 'team': 'DEN', 'player_name': 'Justin Strnad', 'position_abbrev': 'LB', 'age': '24', 'alma_mater': 'Wake Forest', 'player_first_name': 'Justin', 'player_last_name': 'Strnad'}
# {'round': '5', 'pick_number': '179', 'team': 'DAL', 'player_name': 'Bradlee Anae', 'position_abbrev': 'DE', 'age': '21', 'alma_mater': 'Utah', 'player_first_name': 'Bradlee', 'player_last_name': 'Anae'}
# {'round': '6', 'pick_number': '180', 'team': 'CIN', 'player_name': 'Hakeem Adeniji', 'position_abbrev': 'T', 'age': '22', 'alma_mater': 'Kansas', 'player_first_name': 'Hakeem', 'player_last_name': 'Adeniji'}
# {'round': '6', 'pick_number': '181', 'team': 'DEN', 'player_name': 'Netane Muti', 'position_abbrev': 'G', 'age': '21', 'alma_mater': 'Fresno St.', 'player_first_name': 'Netane', 'player_last_name': 'Muti'}
# {'round': '6', 'pick_number': '182', 'team': 'NWE', 'player_name': 'Michael Onwenu', 'position_abbrev': 'G', 'age': '22', 'alma_mater': 'Michigan', 'player_first_name': 'Michael', 'player_last_name': 'Onwenu'}
# {'round': '6', 'pick_number': '183', 'team': 'NYG', 'player_name': 'Cam Brown', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'Penn St.', 'player_first_name': 'Cam', 'player_last_name': 'Brown'}
# {'round': '6', 'pick_number': '184', 'team': 'CAR', 'player_name': 'Bravvion Roy', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Baylor', 'player_first_name': 'Bravvion', 'player_last_name': 'Roy'}
# {'round': '6', 'pick_number': '185', 'team': 'MIA', 'player_name': 'Blake Ferguson', 'position_abbrev': 'LS', 'age': '23', 'alma_mater': 'LSU', 'player_first_name': 'Blake', 'player_last_name': 'Ferguson'}
# {'round': '6', 'pick_number': '186', 'team': 'LAC', 'player_name': 'Alohi Gilman', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Notre Dame', 'player_first_name': 'Alohi', 'player_last_name': 'Gilman'}
# {'round': '6', 'pick_number': '187', 'team': 'CLE', 'player_name': 'Donovan Peoples-Jones', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Michigan', 'player_first_name': 'Donovan', 'player_last_name': 'Peoples-Jones'}
# {'round': '6', 'pick_number': '188', 'team': 'BUF', 'player_name': 'Tyler Bass', 'position_abbrev': 'K', 'age': '23', 'alma_mater': 'Georgia Southern', 'player_first_name': 'Tyler', 'player_last_name': 'Bass'}
# {'round': '6', 'pick_number': '189', 'team': 'JAX', 'player_name': 'Jake Luton', 'position_abbrev': 'QB', 'age': '24', 'alma_mater': 'Oregon St.', 'player_first_name': 'Jake', 'player_last_name': 'Luton'}
# {'round': '6', 'pick_number': '190', 'team': 'SFO', 'player_name': 'Charlie Woerner', 'position_abbrev': 'TE', 'age': '22', 'alma_mater': 'Georgia', 'player_first_name': 'Charlie', 'player_last_name': 'Woerner'}
# {'round': '6', 'pick_number': '191', 'team': 'NYJ', 'player_name': 'Braden Mann', 'position_abbrev': 'P', 'age': '22', 'alma_mater': 'Texas A&M', 'player_first_name': 'Braden', 'player_last_name': 'Mann'}
# {'round': '6', 'pick_number': '192', 'team': 'GNB', 'player_name': 'Jon Runyan', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Michigan', 'player_first_name': 'Jon', 'player_last_name': 'Runyan'}
# {'round': '6', 'pick_number': '193', 'team': 'IND', 'player_name': 'Robert Windsor', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Penn St.', 'player_first_name': 'Robert', 'player_last_name': 'Windsor'}
# {'round': '6', 'pick_number': '194', 'team': 'TAM', 'player_name': 'Khalil Davis', 'position_abbrev': 'DT', 'age': '24', 'alma_mater': 'Nebraska', 'player_first_name': 'Khalil', 'player_last_name': 'Davis'}
# {'round': '6', 'pick_number': '195', 'team': 'NWE', 'player_name': 'Justin Herron', 'position_abbrev': 'T', 'age': '24', 'alma_mater': 'Wake Forest', 'player_first_name': 'Justin', 'player_last_name': 'Herron'}
# {'round': '6', 'pick_number': '196', 'team': 'PHI', 'player_name': 'Shaun Bradley', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Temple', 'player_first_name': 'Shaun', 'player_last_name': 'Bradley'}
# {'round': '6', 'pick_number': '197', 'team': 'DET', 'player_name': 'John Penisini', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Utah', 'player_first_name': 'John', 'player_last_name': 'Penisini'}
# {'round': '6', 'pick_number': '198', 'team': 'PIT', 'player_name': 'Antoine Brooks Jr.', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'Maryland', 'player_first_name': 'Antoine Brooks Jr.', 'player_last_name': 'N/A'}
# {'round': '6', 'pick_number': '199', 'team': 'LAR', 'player_name': 'Jordan Fuller', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Ohio St.', 'player_first_name': 'Jordan', 'player_last_name': 'Fuller'}
# {'round': '6', 'pick_number': '200', 'team': 'PHI', 'player_name': 'Quez Watkins', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Southern Miss', 'player_first_name': 'Quez', 'player_last_name': 'Watkins'}
# {'round': '6', 'pick_number': '201', 'team': 'BAL', 'player_name': 'James Proche', 'position_abbrev': 'WR', 'age': '23', 'alma_mater': 'SMU', 'player_first_name': 'James', 'player_last_name': 'Proche'}
# {'round': '6', 'pick_number': '202', 'team': 'ARI', 'player_name': 'Evan Weaver', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'California', 'player_first_name': 'Evan', 'player_last_name': 'Weaver'}
# {'round': '6', 'pick_number': '203', 'team': 'MIN', 'player_name': 'Blake Brandel', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Oregon St.', 'player_first_name': 'Blake', 'player_last_name': 'Brandel'}
# {'round': '6', 'pick_number': '204', 'team': 'NWE', 'player_name': 'Cassh Maluia', 'position_abbrev': 'LB', 'age': '21', 'alma_mater': 'Wyoming', 'player_first_name': 'Cassh', 'player_last_name': 'Maluia'}
# {'round': '6', 'pick_number': '205', 'team': 'MIN', 'player_name': 'Josh Metellus', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Michigan', 'player_first_name': 'Josh', 'player_last_name': 'Metellus'}
# {'round': '6', 'pick_number': '206', 'team': 'JAX', 'player_name': 'Tyler Davis', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'Georgia Tech', 'player_first_name': 'Tyler', 'player_last_name': 'Davis'}
# {'round': '6', 'pick_number': '207', 'team': 'BUF', 'player_name': 'Isaiah Hodgins', 'position_abbrev': 'WR', 'age': '21', 'alma_mater': 'Oregon St.', 'player_first_name': 'Isaiah', 'player_last_name': 'Hodgins'}
# {'round': '6', 'pick_number': '208', 'team': 'GNB', 'player_name': 'Jake Hanson', 'position_abbrev': 'C', 'age': '23', 'alma_mater': 'Oregon', 'player_first_name': 'Jake', 'player_last_name': 'Hanson'}
# {'round': '6', 'pick_number': '209', 'team': 'GNB', 'player_name': 'Simon Stepaniak', 'position_abbrev': 'T', 'age': '23', 'alma_mater': 'Indiana', 'player_first_name': 'Simon', 'player_last_name': 'Stepaniak'}
# {'round': '6', 'pick_number': '210', 'team': 'PHI', 'player_name': 'Prince Tega Wanogho', 'position_abbrev': 'T', 'age': '22', 'alma_mater': 'Auburn', 'player_first_name': 'Prince Tega Wanogho', 'player_last_name': 'N/A'}
# {'round': '6', 'pick_number': '211', 'team': 'IND', 'player_name': 'Isaiah Rodgers', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Massachusetts', 'player_first_name': 'Isaiah', 'player_last_name': 'Rodgers'}
# {'round': '6', 'pick_number': '212', 'team': 'IND', 'player_name': 'Dezmon Patmon', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Washington St.', 'player_first_name': 'Dezmon', 'player_last_name': 'Patmon'}
# {'round': '6', 'pick_number': '213', 'team': 'IND', 'player_name': 'Jordan Glasgow', 'position_abbrev': 'LB', 'age': '24', 'alma_mater': 'Michigan', 'player_first_name': 'Jordan', 'player_last_name': 'Glasgow'}
# {'round': '6', 'pick_number': '214', 'team': 'SEA', 'player_name': 'Freddie Swain', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Florida', 'player_first_name': 'Freddie', 'player_last_name': 'Swain'}
# {'round': '7', 'pick_number': '215', 'team': 'CIN', 'player_name': 'Markus Bailey', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Purdue', 'player_first_name': 'Markus', 'player_last_name': 'Bailey'}
# {'round': '7', 'pick_number': '216', 'team': 'WAS', 'player_name': 'Kamren Curl', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'Arkansas', 'player_first_name': 'Kamren', 'player_last_name': 'Curl'}
# {'round': '7', 'pick_number': '217', 'team': 'SFO', 'player_name': 'Jauan Jennings', 'position_abbrev': 'WR', 'age': '23', 'alma_mater': 'Tennessee', 'player_first_name': 'Jauan', 'player_last_name': 'Jennings'}
# {'round': '7', 'pick_number': '218', 'team': 'NYG', 'player_name': 'Carter Coughlin', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Minnesota', 'player_first_name': 'Carter', 'player_last_name': 'Coughlin'}
# {'round': '7', 'pick_number': '219', 'team': 'BAL', 'player_name': 'Geno Stone', 'position_abbrev': 'S', 'age': '21', 'alma_mater': 'Iowa', 'player_first_name': 'Geno', 'player_last_name': 'Stone'}
# {'round': '7', 'pick_number': '220', 'team': 'LAC', 'player_name': 'K.J. Hill', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Ohio St.', 'player_first_name': 'K.J.', 'player_last_name': 'Hill'}
# {'round': '7', 'pick_number': '221', 'team': 'CAR', 'player_name': 'Stantley Thomas-Oliver', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Florida International', 'player_first_name': 'Stantley', 'player_last_name': 'Thomas-Oliver'}
# {'round': '7', 'pick_number': '222', 'team': 'ARI', 'player_name': 'Eno Benjamin', 'position_abbrev': 'RB', 'age': '21', 'alma_mater': 'Arizona St.', 'player_first_name': 'Eno', 'player_last_name': 'Benjamin'}
# {'round': '7', 'pick_number': '223', 'team': 'JAX', 'player_name': 'Chris Claybrooks', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'Memphis', 'player_first_name': 'Chris', 'player_last_name': 'Claybrooks'}
# {'round': '7', 'pick_number': '224', 'team': 'TEN', 'player_name': 'Cole McDonald', 'position_abbrev': 'QB', 'age': '', 'alma_mater': 'Hawaii', 'player_first_name': 'Cole', 'player_last_name': 'McDonald'}
# {'round': '7', 'pick_number': '225', 'team': 'MIN', 'player_name': 'Kenny Willekes', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'Michigan St.', 'player_first_name': 'Kenny', 'player_last_name': 'Willekes'}
# {'round': '7', 'pick_number': '226', 'team': 'CHI', 'player_name': 'Arlington Hambright', 'position_abbrev': 'T', 'age': '24', 'alma_mater': 'Colorado', 'player_first_name': 'Arlington', 'player_last_name': 'Hambright'}
# {'round': '7', 'pick_number': '227', 'team': 'CHI', 'player_name': 'Lachavious Simmons', 'position_abbrev': 'G', 'age': '23', 'alma_mater': 'Tennessee St.', 'player_first_name': 'Lachavious', 'player_last_name': 'Simmons'}
# {'round': '7', 'pick_number': '228', 'team': 'ATL', 'player_name': 'Sterling Hofrichter', 'position_abbrev': 'P', 'age': '23', 'alma_mater': 'Syracuse', 'player_first_name': 'Sterling', 'player_last_name': 'Hofrichter'}
# {'round': '7', 'pick_number': '229', 'team': 'WAS', 'player_name': 'James Smith-Williams', 'position_abbrev': 'DE', 'age': '23', 'alma_mater': 'North Carolina St.', 'player_first_name': 'James', 'player_last_name': 'Smith-Williams'}
# {'round': '7', 'pick_number': '230', 'team': 'NWE', 'player_name': 'Dustin Woodard', 'position_abbrev': 'C', 'age': '22', 'alma_mater': 'Memphis', 'player_first_name': 'Dustin', 'player_last_name': 'Woodard'}
# {'round': '7', 'pick_number': '231', 'team': 'DAL', 'player_name': 'Ben DiNucci', 'position_abbrev': 'QB', 'age': '23', 'alma_mater': 'James Madison', 'player_first_name': 'Ben', 'player_last_name': 'DiNucci'}
# {'round': '7', 'pick_number': '232', 'team': 'PIT', 'player_name': 'Carlos Davis', 'position_abbrev': 'DT', 'age': '24', 'alma_mater': 'Nebraska', 'player_first_name': 'Carlos', 'player_last_name': 'Davis'}
# {'round': '7', 'pick_number': '233', 'team': 'PHI', 'player_name': 'Casey Toohill', 'position_abbrev': 'DE', 'age': '24', 'alma_mater': 'Stanford', 'player_first_name': 'Casey', 'player_last_name': 'Toohill'}
# {'round': '7', 'pick_number': '234', 'team': 'LAR', 'player_name': 'Clay Johnston', 'position_abbrev': 'LB', 'age': '24', 'alma_mater': 'Baylor', 'player_first_name': 'Clay', 'player_last_name': 'Johnston'}
# {'round': '7', 'pick_number': '235', 'team': 'DET', 'player_name': 'Jashon Cornell', 'position_abbrev': 'DT', 'age': '23', 'alma_mater': 'Ohio St.', 'player_first_name': 'Jashon', 'player_last_name': 'Cornell'}
# {'round': '7', 'pick_number': '236', 'team': 'GNB', 'player_name': 'Vernon Scott', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'TCU', 'player_first_name': 'Vernon', 'player_last_name': 'Scott'}
# {'round': '7', 'pick_number': '237', 'team': 'KAN', 'player_name': 'Thakarius Keyes', 'position_abbrev': 'CB', 'age': '22', 'alma_mater': 'Tulane', 'player_first_name': 'Thakarius', 'player_last_name': 'Keyes'}
# {'round': '7', 'pick_number': '238', 'team': 'NYG', 'player_name': 'T.J. Brunson', 'position_abbrev': 'LB', 'age': '22', 'alma_mater': 'South Carolina', 'player_first_name': 'T.J.', 'player_last_name': 'Brunson'}
# {'round': '7', 'pick_number': '239', 'team': 'BUF', 'player_name': 'Dane Jackson', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'Pittsburgh', 'player_first_name': 'Dane', 'player_last_name': 'Jackson'}
# {'round': '7', 'pick_number': '240', 'team': 'NOR', 'player_name': 'Tommy Stevens', 'position_abbrev': 'QB', 'age': '23', 'alma_mater': 'Mississippi St.', 'player_first_name': 'Tommy', 'player_last_name': 'Stevens'}
# {'round': '7', 'pick_number': '241', 'team': 'TAM', 'player_name': 'Chapelle Russell', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Temple', 'player_first_name': 'Chapelle', 'player_last_name': 'Russell'}
# {'round': '7', 'pick_number': '242', 'team': 'GNB', 'player_name': 'Jonathan Garvin', 'position_abbrev': 'DE', 'age': '21', 'alma_mater': 'Miami (FL)', 'player_first_name': 'Jonathan', 'player_last_name': 'Garvin'}
# {'round': '7', 'pick_number': '243', 'team': 'TEN', 'player_name': 'Chris Jackson', 'position_abbrev': 'S', 'age': '22', 'alma_mater': 'Marshall', 'player_first_name': 'Chris', 'player_last_name': 'Jackson'}
# {'round': '7', 'pick_number': '244', 'team': 'MIN', 'player_name': 'Nate Stanley', 'position_abbrev': 'QB', 'age': '23', 'alma_mater': 'Iowa', 'player_first_name': 'Nate', 'player_last_name': 'Stanley'}
# {'round': '7', 'pick_number': '245', 'team': 'TAM', 'player_name': 'Raymond Calais', 'position_abbrev': 'RB', 'age': '22', 'alma_mater': 'Louisiana', 'player_first_name': 'Raymond', 'player_last_name': 'Calais'}
# {'round': '7', 'pick_number': '246', 'team': 'MIA', 'player_name': 'Malcolm Perry', 'position_abbrev': 'RB', 'age': '23', 'alma_mater': 'Navy', 'player_first_name': 'Malcolm', 'player_last_name': 'Perry'}
# {'round': '7', 'pick_number': '247', 'team': 'NYG', 'player_name': 'Chris Williamson', 'position_abbrev': 'CB', 'age': '23', 'alma_mater': 'Minnesota', 'player_first_name': 'Chris', 'player_last_name': 'Williamson'}
# {'round': '7', 'pick_number': '248', 'team': 'LAR', 'player_name': 'Sam Sloman', 'position_abbrev': 'K', 'age': '22', 'alma_mater': 'Miami (OH)', 'player_first_name': 'Sam', 'player_last_name': 'Sloman'}
# {'round': '7', 'pick_number': '249', 'team': 'MIN', 'player_name': 'Brian Cole II', 'position_abbrev': 'S', 'age': '23', 'alma_mater': 'Mississippi St.', 'player_first_name': 'Brian Cole II', 'player_last_name': 'N/A'}
# {'round': '7', 'pick_number': '250', 'team': 'LAR', 'player_name': 'Tremayne Anchrum', 'position_abbrev': 'G', 'age': '22', 'alma_mater': 'Clemson', 'player_first_name': 'Tremayne', 'player_last_name': 'Anchrum'}
# {'round': '7', 'pick_number': '251', 'team': 'SEA', 'player_name': 'Stephen Sullivan', 'position_abbrev': 'TE', 'age': '23', 'alma_mater': 'LSU', 'player_first_name': 'Stephen', 'player_last_name': 'Sullivan'}
# {'round': '7', 'pick_number': '252', 'team': 'DEN', 'player_name': 'Tyrie Cleveland', 'position_abbrev': 'WR', 'age': '22', 'alma_mater': 'Florida', 'player_first_name': 'Tyrie', 'player_last_name': 'Cleveland'}
# {'round': '7', 'pick_number': '253', 'team': 'MIN', 'player_name': 'Kyle Hinton', 'position_abbrev': 'G', 'age': '22', 'alma_mater': 'Washburn', 'player_first_name': 'Kyle', 'player_last_name': 'Hinton'}
# {'round': '7', 'pick_number': '254', 'team': 'DEN', 'player_name': 'Derrek Tuszka', 'position_abbrev': 'LB', 'age': '24', 'alma_mater': 'North Dakota St.', 'player_first_name': 'Derrek', 'player_last_name': 'Tuszka'}
# {'round': '7', 'pick_number': '255', 'team': 'NYG', 'player_name': 'Tae Crowder', 'position_abbrev': 'LB', 'age': '23', 'alma_mater': 'Georgia', 'player_first_name': 'Tae', 'player_last_name': 'Crowder'}

# %%
# Out:
#   File "C:\Users\Cameron\AppData\Local\Temp/ipykernel_8316/2998336661.py", line 1
#     pip install pyodbc
#         ^
# SyntaxError: invalid syntax
